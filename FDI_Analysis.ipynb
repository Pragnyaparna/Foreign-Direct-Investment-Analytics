# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('/content/FDI data.csv')

# %%
df.head()
# Out:
#                      Sector  2000-01  2001-02  2002-03  2003-04  2004-05  \
# 0  METALLURGICAL INDUSTRIES    22.69    14.14    36.61     8.11   200.38
# 1                    MINING     1.32     6.52    10.06    23.48     9.92
# 2                     POWER    89.42   757.44    59.11    27.09    43.37
# 3   NON-CONVENTIONAL ENERGY     0.00     0.00     1.70     4.14     1.27
# 4           COAL PRODUCTION     0.00     0.00     0.00     0.04     0.00
#
#    2005-06  2006-07  2007-08  2008-09  2009-10  2010-11  2011-12  2012-13  \
# 0   149.13   169.94  1175.75   959.94   419.88  1098.14  1786.14  1466.23
# 1     7.40     6.62   444.36    34.16   174.40    79.51   142.65    57.89
# 2    72.69   157.15   988.68   907.66  1271.79  1271.77  1652.38   535.68
# 3     1.35     2.44    58.82   125.88   622.52   214.40   452.17  1106.52
# 4     9.14     1.30    14.08     0.22     0.00     0.00     0.00     0.00
#
#    2013-14  2014-15  2015-16  2016-17
# 0   567.63   359.34   456.31  1440.18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Sector   63 non-null     object
#  1   2000-01  63 non-null     float64
#  2   2001-02  63 non-null     float64
#  3   2002-03  63 non-null     float64
#  4   2003-04  63 non-null     float64
#  5   2004-05  63 non-null     float64
#  6   2005-06  63 non-null     float64
#  7   2006-07  63 non-null     float64
#  8   2007-08  63 non-null     float64
#  9   2008-09  63 non-null     float64
#  10  2009-10  63 non-null     float64
#  11  2010-11  63 non-null     float64
#  12  2011-12  63 non-null     float64
#  13  2012-13  63 non-null     float64
#  14  2013-14  63 non-null     float64
#  15  2014-15  63 non-null     float64
#  16  2015-16  63 non-null     float64
#  17  2016-17  63 non-null     float64
# dtypes: float64(17), object(1)
# memory usage: 9.0+ KB

# %%
df.describe()
# Out:
#           2000-01     2001-02     2002-03     2003-04     2004-05  \
# count   63.000000   63.000000   63.000000   63.000000   63.000000
# mean    37.757302   63.931587   42.925714   34.727778   51.090317
# std    112.227860  157.878737   86.606439   67.653735  101.934873
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.200000    0.215000    0.715000
# 50%      4.030000    5.070000   11.010000    6.370000    9.090000
# 75%     23.510000   44.830000   36.555000   38.660000   43.205000
# max    832.070000  873.230000  419.960000  368.320000  527.900000
#
#            2005-06      2006-07      2007-08      2008-09      2009-10  \
# count    63.000000    63.000000    63.000000    63.000000    63.000000
# mean     87.932540   198.281905   390.085714   498.348571   410.069524
# std     206.436967   686.783115  1026.249935  1134.649040   926.814626
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Sector     0
# 2000-01    0
# 2001-02    0
# 2002-03    0
# 2003-04    0
# 2004-05    0
# 2005-06    0
# 2006-07    0
# 2007-08    0
# 2008-09    0
# 2009-10    0
# 2010-11    0
# 2011-12    0
# 2012-13    0
# 2013-14    0
# 2014-15    0
# 2015-16    0
# 2016-17    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.set_index('Sector', inplace=True)

# %%
df.head()
# Out:
#                           2000-01  2001-02  2002-03  2003-04  2004-05  \
# Sector
# METALLURGICAL INDUSTRIES    22.69    14.14    36.61     8.11   200.38
# MINING                       1.32     6.52    10.06    23.48     9.92
# POWER                       89.42   757.44    59.11    27.09    43.37
# NON-CONVENTIONAL ENERGY      0.00     0.00     1.70     4.14     1.27
# COAL PRODUCTION              0.00     0.00     0.00     0.04     0.00
#
#                           2005-06  2006-07  2007-08  2008-09  2009-10  \
# Sector
# METALLURGICAL INDUSTRIES   149.13   169.94  1175.75   959.94   419.88
# MINING                       7.40     6.62   444.36    34.16   174.40
# POWER                       72.69   157.15   988.68   907.66  1271.79
# NON-CONVENTIONAL ENERGY      1.35     2.44    58.82   125.88   622.52
# COAL PRODUCTION              9.14     1.30    14.08     0.22     0.00
#
#                           2010-11  2011-12  2012-13  2013-14  2014-15  \
# Sector
# ...

# %%
df=df.transpose()

# %%
df.describe()
# Out:
# Sector  METALLURGICAL INDUSTRIES      MINING        POWER  \
# count                  17.000000   17.000000    17.000000
# mean                  607.678824  133.637059   681.713529
# std                   590.318680  209.032041   524.452076
# min                     8.110000    1.320000    27.090000
# 25%                   149.130000    9.920000    89.420000
# 50%                   419.880000   34.160000   757.440000
# 75%                  1098.140000  142.650000  1066.080000
# max                  1786.140000  684.390000  1652.380000
#
# Sector  NON-CONVENTIONAL ENERGY  COAL PRODUCTION  PETROLEUM & NATURAL GAS  \
# count                 17.000000        17.000000                17.000000
# mean                 304.793529         1.631765               403.303529
# std                  359.716927         3.929237               568.490900
# min                    0.000000         0.000000                 9.350000
# ...

# %%
df['Total FDI']=df.sum(axis=1)
yearly_total=df['Total FDI']
plt.figure(figsize=(10,6))
yearly_total.plot(kind='bar')
plt.title('Total FDI In India(2000-01 to 2016-17)')
plt.xlabel('Finanacial Year')
plt.ylabel('Total FDI(in million USD)')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.lineplot(data = yearly_total)
plt.xticks(rotation = 45)
plt.title('Total FDI in India (2000-01 to 2016-17)')
plt.xlabel('Financial Year')
plt.ylabel('Total FDI (in million USD)')
plt.show()

# %%
#Top 5 Best performing years
sorted = df.sort_values(by='Total FDI', ascending=False)
sorted.head()
# Out:
# Sector   METALLURGICAL INDUSTRIES  MINING    POWER  NON-CONVENTIONAL ENERGY  \
# 2016-17                   1440.18   55.75  1112.98                   783.57
# 2015-16                    456.31  520.67   868.80                   776.51
# 2011-12                   1786.14  142.65  1652.38                   452.17
# 2008-09                    959.94   34.16   907.66                   125.88
# 2014-15                    359.34  684.39   707.04                   615.95
#
# Sector   COAL PRODUCTION  PETROLEUM & NATURAL GAS  \
# 2016-17             0.00                   180.40
# 2015-16             0.00                   103.02
# 2011-12             0.00                  2029.98
# 2008-09             0.22                   349.29
# 2014-15             0.00                  1079.02
#
# Sector   BOILERS AND STEAM GENERATING PLANTS  \
# 2016-17                                53.91
# 2015-16                                77.91
# 2011-12                                31.79
# ...

# %%
#top 5 catagories from sector but remove total fdi sector
Top5_catagory=df.drop('Total FDI', axis=1).sum(axis=0)
Top5_catagory = Top5_catagory.sort_values(ascending=False).head()
Top5_catagory
# Out:
# Sector
# SERVICES SECTOR (Fin.,Banking,Insurance,Non Fin/Business,Outsourcing,R&D,Courier,Tech. Testing and Analysis, Other)    59476.49
# COMPUTER SOFTWARE & HARDWARE                                                                                           24669.49
# CONSTRUCTION DEVELOPMENT: Townships, housing, built-up infrastructure and construction-development projects            24293.09
# TELECOMMUNICATIONS                                                                                                     23946.01
# AUTOMOBILE INDUSTRY                                                                                                    16673.92
# dtype: float64

# %%
Top5_catagory.rename(index={'SERVICES SECTOR (Fin.,Banking,Insurance,Non Fin/Business,Outsourcing,R&D,Courier,Tech. Testing and Analysis, Other)': 'SERVICES SECTOR', 'CONSTRUCTION DEVELOPMENT: Townships, housing, built-up infrastructure and construction-development projects': 'CONSTRUCTION DEVELOPMENT'}, inplace = True)
plt.figure(figsize=(10,6))
sns.barplot(data = Top5_catagory)
plt.title('Top 5 Sectors with Highest FDI')
plt.xlabel('Sector')
plt.ylabel('Total FDI (in million USD)')
plt.xticks(rotation = 45)
plt.show()

# %%
#add a total fdi column
df['Total FDI']=df.sum(axis=1)
df
df.head()
# Out:
# Sector   METALLURGICAL INDUSTRIES  MINING   POWER  NON-CONVENTIONAL ENERGY  \
# 2000-01                     22.69    1.32   89.42                     0.00
# 2001-02                     14.14    6.52  757.44                     0.00
# 2002-03                     36.61   10.06   59.11                     1.70
# 2003-04                      8.11   23.48   27.09                     4.14
# 2004-05                    200.38    9.92   43.37                     1.27
#
# Sector   COAL PRODUCTION  PETROLEUM & NATURAL GAS  \
# 2000-01             0.00                     9.35
# 2001-02             0.00                   211.07
# 2002-03             0.00                    56.78
# 2003-04             0.04                    80.64
# 2004-05             0.00                   102.78
#
# Sector   BOILERS AND STEAM GENERATING PLANTS  \
# 2000-01                                 0.00
# 2001-02                                 0.00
# 2002-03                                 0.00
# ...

# %%
df.describe()
# Out:
# Sector  METALLURGICAL INDUSTRIES      MINING        POWER  \
# count                  17.000000   17.000000    17.000000
# mean                  607.678824  133.637059   681.713529
# std                   590.318680  209.032041   524.452076
# min                     8.110000    1.320000    27.090000
# 25%                   149.130000    9.920000    89.420000
# 50%                   419.880000   34.160000   757.440000
# 75%                  1098.140000  142.650000  1066.080000
# max                  1786.140000  684.390000  1652.380000
#
# Sector  NON-CONVENTIONAL ENERGY  COAL PRODUCTION  PETROLEUM & NATURAL GAS  \
# count                 17.000000        17.000000                17.000000
# mean                 304.793529         1.631765               403.303529
# std                  359.716927         3.929237               568.490900
# min                    0.000000         0.000000                 9.350000
# ...

# %%
# Out:
# Sector
# SERVICES SECTOR                  59476.49
# COMPUTER SOFTWARE & HARDWARE     24669.49
# CONSTRUCTION DEVELOPMENT         24293.09
# TELECOMMUNICATIONS               23946.01
# AUTOMOBILE INDUSTRY              16673.92
# Total FDI                       149059.00
# dtype: float64

# %%
#save to csv file
df.to_csv('FDI_cleaned.csv')
